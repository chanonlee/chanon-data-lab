# %%
import torch
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# %%
# 将数据集转换为张量
transform = transforms.Compose([transforms.ToTensor()])

# 下载数据集
trainset = datasets.MNIST('-/.pytorch/MNIST_data/', download= True, train= True, transform= transform)
# 将数据集加载到内存中
trainloader = torch.utils.data.DataLoader(trainset, batch_size = 64, shuffle= True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:09<00:00, 1.07MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 62.4kB/s]
# 100%|██████████| 1.65M/1.65M [00:04<00:00, 398kB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 524kB/s]

# %%
dataiter = iter(trainloader)
# 获取一批数据
images, labels = next(dataiter)
# 为啥images的shape是(64, 1, 28, 28)？
# 64张，1种颜色，28*28像素
print(images.shape)
print(labels.shape)
plt.imshow(images[1].numpy().squeeze(), cmap ='Greys_r')
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64])

# %%
from torch.utils.data import Dataset
import random
class SampleDataset(Dataset):
    def __init__(self, r1, r2):
        randomlist = []
        for i in range(120):
            n = random.randint(r1,r2)
            randomlist.append(n)
        self.samples= randomlist
    def __len__(self):
        return len(self.samples)
    def __getitem__(self, idx):
        return(self.samples[idx])
dataset= SampleDataset(1,100)
print(dataset[100:120])
# Out:
# [64, 72, 67, 53, 80, 23, 60, 76, 9, 99, 13, 57, 25, 58, 75, 54, 55, 91, 3, 78]
