# %% [markdown]
# # LLM 直接文本提示（无 PromptTemplate）

# %%
from llm_config import build_chat_openai

# =====================模型层=====================
# 此处可设置为本地模型或远程模型

llm = build_chat_openai(temperature=1)

# =====================提示层=====================
prompt_text = "写一首关于鸭子的悲伤的诗"

# =====================调用层=====================
response = llm.invoke(prompt_text)

# =====================输出层=====================
print(response.content)
# Out:
# **《水辙》**
#
# 你浮在冷下来的水面，
# 羽毛像一封未寄出的信。
# 曾经成群的倒影早已走散，
# 只剩你，一圈圈划开寂静。
#
# 那声低鸣不是呼唤，
# 是喉间咽下的旧年。
# 水月不答，芦苇垂首，
# 连风也绕开你的孤单。
#
# 你记得春泥里的交颈，
# 记得雏羽破壳的微光。
# 如今巢空了，水温了又凉，
# 你把思念，啄成水底的霜。
#
# 不怨候鸟不回头，
# 不怨池塘渐干涸。
# 你只轻轻理了理湿透的翅，
# 向暮色，游成一道沉默的辙。
